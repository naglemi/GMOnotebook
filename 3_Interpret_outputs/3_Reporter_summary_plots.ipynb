# %% [markdown]
# # Summary statistics of regeneration and transformation frequencies across plates (petri dishes)

# %% [markdown]
# Both types of statistics (regeneration and transformation frequencies) are computed over whole plates, which may contain 12 or 20 explants, or fewer depending on [scripts or user-provided data](https://github.com/naglemi/GMOnotebook/blob/master/1_Decide_parameters/3_Other_parameters/2_Missing_or_contaminated_explants.ipynb) for missing/contaminated explants

# %% [markdown]
# Boxplots and violin plots are provided.
#
# In boxplots, each datapoint (a given plate) is represented by a small black dot, while means are represented by a large black dot. Boxes represent the interquartile range (IQR) from the 0.25 to 0.75 quantile and whiskers show a range of 1.5\*IQR. The line in the middle of boxes represents the median.
#
# In violin plots, the distribution of data is represented by thickness of the "violin" instead of by a box and whiskers. The black dot in each violin represents the mean.

# %% [markdown]
# ## Regeneration frequency

# %% [markdown]
# Regeneration summary statistics pay no respect to hyperspectral signal, and represent how many grid spots (each with an explant) are positive for a particular tissue type.
#
# For example, these statistics will include "escapes" that have produced shoot but do not carry a fluorescent reporter.![2B1_portion_Shoot_total.png](attachment:10b82ff3-362b-47ca-b91d-c7f97b1ba539.png)

# %% [markdown]
# ## Transformation frequency

# %% [markdown]
# Transformation summary statistics are determined using user-provided significance thresholds previously described (`reporter_threshold` and `pixel_threshold`). In short, if a certain number of pixels have a certain level of signal indicative of a reporter protein, the tissue with those pixels is considered to be positive for the reporter protein.
# ![2B2_portion_Shoot_transgenic.png](attachment:c30e671f-db74-4694-8c4b-dae0b2d00e94.png)
