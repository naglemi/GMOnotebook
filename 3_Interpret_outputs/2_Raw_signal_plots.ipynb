# %% [markdown]
# # Interpreting "raw signal" plots

# %% [markdown]
# These plots present summary statistics of tissue development and fluorescent protein content for each type of tissue (e.g. callus, shoot and unregenerated stem). One of each plot described below will be produced for every tissue type.<br><br>
# These statistics are computed and plotted for each explant. These are in contrast to the transformation frequency summary plots (described next) which provide aggregate statistics over whole plates.

# %% [markdown]
# For each of these plots, individual explants are repsented by a small black dot. Mean values are represented by a larger black dot. Boxes represent interquartile ranges (IQR; 0.25 quartile to 0.75 quartile) while whiskers represent an area of 1.5\*IQR. The black line in the middle of each box represents the median, and may not be easily visible if the median value is zero or near-zero.

# %% [markdown]
# ## Total protein signal

# %% [markdown]
# ![A1_Shoot_Total_signal.png](attachment:febe55bb-42eb-47cb-bf60-892350446ec5.png)

# %% [markdown]
# "Total protein signal" refers to the sum of weights for a given reporter protein over all segments of a given tissue for a given explant. Note, this can be a noisy statistic because it will include supposed protein signal that does not pass significance thresholds and is in fact background noise. For a more biologically informative statistic, see "Number of pixels with strong signal".

# %% [markdown]
# ## Mean protein signal

# %% [markdown]
# ![C1_Shoot_Mean_signal.png](attachment:0c82f69f-6e1d-430b-a00e-9505ea57c95c.png)

# %% [markdown]
# "Mean protein signal" refers to the mean weight of a given reporter protein across segments of a given tissue of a given explant.

# %% [markdown]
# ## Maximum protein signal

# %% [markdown]
# ![B1_Shoot_Max_signal.png](attachment:7d5ed43c-cb9e-487a-b42f-0534a2b90daf.png)

# %% [markdown]
# The maximum signal represented by this plot is the reporter protein weight for the pixel of a given tissue type for a given explant with the strongest signal.

# %% [markdown]
# ## Total pixels

# %% [markdown]
# ![A1_Shoot_Total_pixels.png](attachment:0140c487-d173-4f86-b6ae-ae188b46e4f3.png)

# %% [markdown]
# Statistics of "total pixels" pay no respect to hyperspectral signal. These statistics represent the total number of pixels for a given tissue type in each explant, as determined by semantic segmentation.

# %% [markdown]
# ## Number of pixels with strong signal

# %% [markdown]
# ![A1_Shoot_pixels_w_strong_signal.png](attachment:9a4b9266-91c0-4370-876b-85c691fb60ee.png)

# %% [markdown]
# This statistic may be the most informative to researchers of plant transformation and regeneration, because it provides a measure of development of a particular tissue type with significant transgenic signal. The threshold for significance can be set by the user as [previously described](https://github.com/naglemi/GMOnotebook/blob/master/1_Decide_parameters/3_Other_parameters/3_Hyperspectral_settings.ipynb). For each explant, this statistic provides a count of pixels of a given tissue type with reporter signal passing this user-defined significance threshold.
