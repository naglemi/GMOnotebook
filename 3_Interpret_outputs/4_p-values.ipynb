# %% [markdown]
# # Empirical *p*-values for treatment effects and interactions with genotype

# %% [markdown]
# A certain level of statistical analysis is automatically performed for the user. This includes linear regression and ANOVA, with empirical *p*-values calculated using the `permutes` package. The use of empirical *p*-values, computed by permutations and generation of a true null distribution, avoids any assumptions of data distributions and should thus be robust for the diverse distributions `GMOdetector` output statistics may follow.

# %% [markdown]
# ANOVA and linear regression results are provided in separate spreadsheets for the whole-plate transformation frequency statistics and the per-explant summary statistics previously described.

# %% [markdown]
# See below examples of portions of the ANOVA table results. Of greatest interest to the user are the empirical p-values, which are shown here for both block and experiment, and are also computed for background genotype and genotype\*treatment interaction terms for experiments with multiple genotypes.

# %% [markdown]
# ## Regeneration, transformation frequency statistics

# %% [markdown]
# ![Screenshot from 2022-10-16 17-07-28.png](attachment:eec72d81-95d9-4339-8c0b-029dab218b8c.png)

# %% [markdown]
# ## Explant-level summary statistics

# %% [markdown]
# Note: The same statistics are provided for each tissue type here. Thus, there is an additional column for tissue.

# %% [markdown]
# ![Screenshot from 2022-10-16 17-35-31.png](attachment:5f6d21d3-fe9c-473b-8f74-2b24743f7212.png)
