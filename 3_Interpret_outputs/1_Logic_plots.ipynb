# %% [markdown]
# # Interpreting logic plots

# %% [markdown]
# A logic plot for each explant is produced by the [`GMOlabeler` module](https://github.com/naglemi/GMOlabeler), which is responsible for integrating RGB and hyperspectral data layers and determining whether a given tissue is transgenic or not. Examination of these plots can be useful to:
# - Understand why `GMOlabeler` decides a given tissue is transgenic or not
# - Make sure alignment of RGB and hyperspectral layers is accurate
# - Make sure cropping to grid spots (each generally containing an explant) is accurate

# %% [markdown]
# See below an example of a logic plot for a sample with transgenic shoot. ![Screenshot from 2022-09-26 19-19-54.png](attachment:5e4ec67f-4e57-46de-8e9f-08d7f3ffa0f2.png)

# %% [markdown]
# There are eight cells in this plot. These show:
# 1. RGB image
# 2. Grid view: The RGB image with the grid superimposed. We use numbered grids and can make sure the number for the grid matches the ID for the explant. To ensure cropping works as expected, we can see that the borders of the grid are at the edges of the cell, and that the explant is at or near the middle of the grid spot.
# 3. Segments: Output from the `DeepLabv3+` semantic segmentation model, in our case classifying each pixel as shoot (green), callus (blue), or unregenerated stem (red).
# 4. Fluorescent view: This shows a type of false-color image, based on hyperspectral data, intended to mimic what one would see when viewing the sample under a fluorescent microscope. Here, GFP (or other user-specified reporter protein) appears green, while chlorophyll is red.
# 5. GFP weight: The raw signal for GFP or GFP-like signal is shown for all pixels. Brighter pixels indicate a greater amount of GFP or GFP-like signal.
# 6. GFP or GFP-like weight is shown for each tissue segment.

# %% [markdown]
# The outputs of these plots will depend on the user's selection of the relevant reporter protein and *cap* parameters for each spectral component, as described in [previous tutorials](https://github.com/naglemi/GMOnotebook/tree/master/1_Decide_parameters/3_Other_parameters).
