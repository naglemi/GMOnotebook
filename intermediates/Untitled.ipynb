# %%
import os
import sys
from PIL import Image

# %%
file_path = "/run/media/labgroup/Elements_7/Transformation/FAD_Dev_Genes/wk3/Fluorescent/FAD1_I5.0_F1.9_L100_141910_0_0_0_rgb.jpg"

# %%
file_in = Image.open(file_path).convert("RGB")
file_in = file_in.resize((900,900))

# %%
file_in
# Out:
# <PIL.Image.Image image mode=RGB size=900x900 at 0x7F8988A71850>

# %%
file_in.getexif()

# %%
import piexif

# %%
import pexif
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-15f33399622e> in <module>
# ----> 1 import pexif
#
# ModuleNotFoundError: No module named 'pexif'

# %%
file_in = file_in.rotate(180)
file_in = file_in.crop((0, 150, 900, 750))
