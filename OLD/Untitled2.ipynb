# %% [markdown]
# # Find good parameters for `--crop-dims` of `inference.py` in `DenseNet` repo for detecting missing or contaminated explants

# %%
from PIL import Image

# %%
my_grid = Image.open("/run/media/labgroup/Elements_9/Transformation/FAC_Dev_Genes/wk10/Fluorescent/chromagrid_I5.0_F1.9_L100_133619_0_0_0_rgb.jpg")

# %%
preprocessed_img = my_grid.rotate(270).resize((2000,2000))

# %%
cropped_img = preprocessed_img.crop((275,438,1725,1535))

# %%
cropped_img
# Out:
# <PIL.Image.Image image mode=RGB size=1450x1097 at 0x7F5A081B4550>
