# %% [markdown]
# # Find good parameters for `distance` and `gaussian_sigma` for RGB/hyperspectral alignment

# %% [markdown]
# <div class="alert alert-block alert-info"> In this version of notebook (a2), I screen parameters for the distance parameter in addition to the gaussian_sigma parameter.  </div>

# %%
conda activate alignment
# Out:
# (alignment)
# : 1

# %%
cd ~/code/ImageAlignment
# Out:
# (alignment)
# : 1

# %% [markdown]
# We will test a range of values for both `distance` and `gaussian_sigma` and see how well each of them work for alignment.

# %%
for i in $(seq 0.5 0.05 1.5)
  do echo "gaussian_sigma will be"
  echo $i
  for j in $(seq 0 0.05 1)
    do echo "distance will be"
    echo $j
    #rm output/chromagrid_I5.0_F1.9_L100_133619*
    python main.py \
    --hyper-img '/run/media/labgroup/Elements_9//Transformation/GRF_Poplar/GRF1_Phase_2/wk3/hypercube_to_csv.csv' \
    --rgb-img '/run/media/labgroup/Elements_9//Transformation/GRF_Poplar/GRF1_Phase_2/wk3/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb.jpg' \
    --mode 1 \
    --image_thresh_high=120 \
    --image_thresh_low=50 \
    --distance=$j \
    --gaussian_sigma $i
    outname_old="output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg"
    outname=$(echo $outname_old | sed "s/.jpg/_gs${i}_dis${j}.jpg/g")
    mv $outname_old $outname
    echo "Writing to"
    echo $outname
    #display < outname
    echo ""
    done
  done
# Out:
# gaussian_sigma will be
# 0.50
# distance will be
# 0.00
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.00.jpg
#
# distance will be
# 0.05
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.05.jpg
#
# distance will be
# 0.10
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.10.jpg
#
# distance will be
# 0.15
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.15.jpg
#
# distance will be
# 0.20
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.20.jpg
#
# distance will be
# 0.25
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.25.jpg
#
# distance will be
# 0.30
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.30.jpg
#
# distance will be
# 0.35
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.35.jpg
#
# distance will be
# 0.40
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.40.jpg
#
# distance will be
# 0.45
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.45.jpg
#
# distance will be
# 0.50
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-1.17584630e+00  3.35049801e-03  1.04624027e+03]
#  [ 5.42710112e-01 -3.57997499e-01 -3.63355888e+02]
#  [-1.14761788e-03  4.25877484e-05  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.50.jpg
#
# distance will be
# 0.55
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[ 3.26983480e+00 -2.15636877e-03 -1.19728484e+03]
#  [ 1.45316543e+00  1.95093622e+00 -1.70694368e+03]
#  [ 9.27812861e-04 -5.57712665e-06  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.55.jpg
#
# distance will be
# 0.60
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-1.07629675e+00  8.90839537e-01  9.19627999e+02]
#  [-5.19082914e-01  1.48399696e+00 -2.89747897e+02]
#  [-1.05529567e-03  7.47892613e-04  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.60.jpg
#
# distance will be
# 0.65
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-5.18556030e-01 -2.00654367e-01  1.04317924e+03]
#  [-5.15713743e-01  3.72845700e-01  4.82792483e+02]
#  [-5.23527872e-04 -1.79865319e-04  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.65.jpg
#
# distance will be
# 0.70
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-4.80481805e-02 -6.32751799e-01  9.70275712e+02]
#  [ 8.03296810e-02  1.14858304e-01  7.85730538e+01]
#  [-1.55173562e-04 -5.85944958e-04  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.70.jpg
#
# distance will be
# 0.75
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-5.17705527e-01  2.31767525e-02  7.29418719e+02]
#  [-8.58291106e-02  1.23571451e-02  2.91659611e+02]
#  [-5.84713810e-04 -2.26475082e-04  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.75.jpg
#
# distance will be
# 0.80
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-1.49070101e+00  8.67880032e-01  2.56966081e+03]
#  [ 3.69540762e-01  3.68413676e+00 -8.99307211e+01]
#  [-2.22965984e-04  1.53967423e-03  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.80.jpg
#
# distance will be
# 0.85
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-1.62809582e-01 -8.30282987e-03  2.50094136e+02]
#  [-2.00956862e-01 -3.07450141e-02  3.20566802e+02]
#  [-5.81055088e-04 -1.31022471e-04  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.85.jpg
#
# distance will be
# 0.90
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-3.55085711e-01  7.19799024e-03  5.05521211e+02]
#  [-2.83012783e-01  2.63419851e-02  5.12671483e+02]
#  [-6.18266230e-04 -2.45454862e-05  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.90.jpg
#
# distance will be
# 0.95
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-1.93511729e-02 -7.96600286e-03  2.57547345e+01]
#  [-5.48068111e-01 -9.34188315e-02  7.55853755e+02]
#  [-7.22276458e-04 -1.27069307e-04  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis0.95.jpg
#
# distance will be
# 1.00
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-3.78760097e-01  1.98894307e-01  5.54825670e+01]
#  [-2.51683220e+00  8.92753845e-01  1.24962844e+03]
#  [-2.41308176e-03  9.61763736e-04  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.50_dis1.00.jpg
#
# gaussian_sigma will be
# 0.55
# distance will be
# 0.00
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.00.jpg
#
# distance will be
# 0.05
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.05.jpg
#
# distance will be
# 0.10
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.10.jpg
#
# distance will be
# 0.15
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.15.jpg
#
# distance will be
# 0.20
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.20.jpg
#
# distance will be
# 0.25
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.25.jpg
#
# distance will be
# 0.30
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.30.jpg
#
# distance will be
# 0.35
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.35.jpg
#
# distance will be
# 0.40
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.40.jpg
#
# distance will be
# 0.45
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.45.jpg
#
# distance will be
# 0.50
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-1.24613211e+00 -3.39346503e-01  1.18257160e+03]
#  [-1.36572708e+00 -8.54892154e-01  1.81325696e+03]
#  [-9.80775300e-04 -4.01841446e-04  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.50.jpg
#
# distance will be
# 0.55
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-5.29005036e-01 -4.46168341e-01  1.08670761e+03]
#  [-6.56786527e-01 -6.48215578e-01  1.44202949e+03]
#  [-5.05719017e-04 -3.59183143e-04  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.55.jpg
#
# distance will be
# 0.60
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[ 1.15893974e+00 -8.73005446e-04 -9.82726888e+01]
#  [-1.57543100e-02  9.91700087e-01 -9.53835580e+01]
#  [-1.20893195e-05 -2.88139688e-06  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.60.jpg
#
# distance will be
# 0.65
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[ 1.17765221e+00 -2.25983104e-03 -1.04288721e+02]
#  [-7.45084635e-03  1.00089954e+00 -1.03821874e+02]
#  [-4.30252188e-07 -3.62436568e-06  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.65.jpg
#
# distance will be
# 0.70
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[ 1.21239311e+00 -3.48260783e-01  9.32822926e+01]
#  [-7.10506476e-01  8.07616255e-01  7.38562172e+02]
#  [ 2.00905567e-04 -3.11336897e-04  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.70.jpg
#
# distance will be
# 0.75
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-5.05918544e+01 -3.09047079e+02  6.17624182e+03]
#  [-1.38778333e+02 -3.53883773e+02  1.71791293e+04]
#  [-8.79007598e-02 -2.75797068e-01  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.75.jpg
#
# distance will be
# 0.80
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-5.04401126e-01  3.60035316e-03  6.99447698e+02]
#  [-1.91709435e-01  6.33887181e-03  2.69773005e+02]
#  [-7.18512071e-04 -2.98482313e-06  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.80.jpg
#
# distance will be
# 0.85
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-1.42076954e-02 -1.74657486e-01  3.44268645e+02]
#  [-3.14351701e-01 -5.14436806e-01  1.14518464e+03]
#  [-3.21779468e-04 -4.39647621e-04  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.85.jpg
#
# distance will be
# 0.90
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[ 5.16982680e-01 -1.13774471e+00  6.32474828e+02]
#  [ 5.65144759e-01 -1.01248912e+00  4.50601641e+02]
#  [ 8.63240225e-04 -1.95888204e-03  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.90.jpg
#
# distance will be
# 0.95
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-4.68569158e-01 -8.11333694e-01  5.96804710e+02]
#  [-4.77061696e-01 -7.39121488e-01  5.84190941e+02]
#  [-8.18238920e-04 -1.25292690e-03  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis0.95.jpg
#
# distance will be
# 1.00
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-1.34222218e-01 -3.33098835e+00  4.06592281e+01]
#  [ 3.86783181e-01 -6.19372891e+01  1.28653385e+03]
#  [-3.18561786e-04 -4.69872246e-02  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.55_dis1.00.jpg
#
# gaussian_sigma will be
# 0.60
# distance will be
# 0.00
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.00.jpg
#
# distance will be
# 0.05
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.05.jpg
#
# distance will be
# 0.10
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.10.jpg
#
# distance will be
# 0.15
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.15.jpg
#
# distance will be
# 0.20
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.20.jpg
#
# distance will be
# 0.25
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.25.jpg
#
# distance will be
# 0.30
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.30.jpg
#
# distance will be
# 0.35
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.35.jpg
#
# distance will be
# 0.40
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.40.jpg
#
# distance will be
# 0.45
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.45.jpg
#
# distance will be
# 0.50
# ------------Preprocess is saved and finished.-------------------
# No of matches are less than 4. Cannot run RANSAC
# mv: cannot stat 'output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned.jpg': No such file or directory
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.50.jpg
#
# distance will be
# 0.55
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-1.09197941e+00 -6.04428925e-01  1.23433140e+03]
#  [-8.77450980e-01 -7.01879256e-01  1.23094952e+03]
#  [-8.93045431e-04 -5.22009195e-04  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.55.jpg
#
# distance will be
# 0.60
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[ 1.32926382e+00  1.32391864e-03 -2.12760648e+02]
#  [ 4.66476664e-02  1.04811277e+00 -1.67036959e+02]
#  [ 4.02693184e-05 -1.12854129e-06  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.60.jpg
#
# distance will be
# 0.65
# ------------Preprocess is saved and finished.-------------------
# Homography :
#  [[-7.54512572e-01 -4.59561157e-03  9.26638500e+02]
#  [-3.31082025e-01  1.39076304e-01  3.22646833e+02]
#  [-8.40203023e-04 -4.45347111e-06  1.00000000e+00]]
#
# Saving aligned image and homography matrix at:
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb
# Writing to
# output/chromagrid_I5.0_F1.9_L100_170217_0_0_0_rgb_aligned_gs0.60_dis0.65.jpg
#
# distance will be
# 0.70
# ------------Preprocess is saved and finished.-------------------
